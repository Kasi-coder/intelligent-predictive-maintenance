# %% [markdown]
# # 02 — Preprocessing and Feature Engineering

# %%
import pandas as pd
from src.preprocessing import make_features, IQRClipper
df=pd.read_csv('../data/ai4i2020_reproducible.csv')
X=make_features(df)
X.head()

# %%
clipper=IQRClipper().fit(X)
X_clipped=clipper.transform(X)
X_clipped.describe().T
