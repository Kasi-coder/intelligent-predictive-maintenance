# %% [markdown]
# # 03 — Feature Engineering and Selection

# %%
import pandas as pd
from src.preprocessing import make_features
df=pd.read_csv('../data/ai4i2020_reproducible.csv')
X=make_features(df)
print(X.columns.tolist())

# %%
# Failure-mode columns are excluded to prevent target leakage.
print('Selected model inputs:', X.columns.tolist())
