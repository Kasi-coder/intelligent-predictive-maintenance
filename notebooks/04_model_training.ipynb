# %% [markdown]
# # 04 — Model Training and Evaluation

# %%
import json
from pathlib import Path
results=json.loads(Path('../reports/model_comparison.json').read_text())
results

# %% [markdown]
# The repository model artifact is already trained. To retrain, run `python -m src.train` from the project root.
